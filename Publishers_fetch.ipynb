# %% [markdown]
# <a href="https://colab.research.google.com/github/sha-linimoorthy/Website-Analyser/blob/main/Publishers_fetch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_csv("/content/publishers.txt",sep=";",on_bad_lines='skip')
df
# Out:
#         Rank     Sourceid                                              Title  \
# 0          1        28773                 Ca-A Cancer Journal for Clinicians
# 1          2        20315              Nature Reviews Molecular Cell Biology
# 2          3        29431                     Quarterly Journal of Economics
# 3          4        18434                                               Cell
# 4          6        15847                    New England Journal of Medicine
# ...      ...          ...                                                ...
# 27333  27335       144807                  WSEAS Transactions on Electronics
# 27334  27336       144808  WSEAS Transactions on Information Science and ...
# 27335  27337       144813                      WSEAS Transactions on Systems
# 27336  27338  21101046690  Z Badan nad Ksiazka i Ksiegozbiorami Historycz...
# 27337  27339        20904  Zhongguo ji sheng chong xue yu ji sheng chong ...
#
# ...

# %%
df_new=df.iloc[:,15:18]
df_new
# Out:
#               Country            Region  \
# 0       United States  Northern America
# 1      United Kingdom    Western Europe
# 2      United Kingdom    Western Europe
# 3       United States  Northern America
# 4       United States  Northern America
# ...               ...               ...
# 27333          Greece    Western Europe
# 27334          Greece    Western Europe
# 27335          Greece    Western Europe
# 27336          Poland    Eastern Europe
# 27337           China    Asiatic Region
#
#                                                Publisher
# 0                                        Wiley-Blackwell
# 1                                Nature Publishing Group
# 2                                Oxford University Press
# 3                                             Cell Press
# 4                         Massachussetts Medical Society
# ...                                                  ...
# 27333  World Scientific and Engineering Academy and S...
# ...

# %%
df_new.to_csv("/content/publishers.csv",index=True)

# %%
df_new
# Out:
#               Country            Region  \
# 0       United States  Northern America
# 1      United Kingdom    Western Europe
# 2      United Kingdom    Western Europe
# 3       United States  Northern America
# 4       United States  Northern America
# ...               ...               ...
# 27333          Greece    Western Europe
# 27334          Greece    Western Europe
# 27335          Greece    Western Europe
# 27336          Poland    Eastern Europe
# 27337           China    Asiatic Region
#
#                                                Publisher
# 0                                        Wiley-Blackwell
# 1                                Nature Publishing Group
# 2                                Oxford University Press
# 3                                             Cell Press
# 4                         Massachussetts Medical Society
# ...                                                  ...
# 27333  World Scientific and Engineering Academy and S...
# ...

# %%
df_new=df.iloc[:,17]
df_new.to_csv("/content/publishers_name.csv")
